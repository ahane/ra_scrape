# %%
event_db_url = 'http://localhost:5000/api/'

# %%
def get_resident_advisor(url=event_db_url):
    ra = get(url + 'third_party/' + quote('Resident Advisor'))
    if not ra.ok:
        ra_dict = json.dumps({'name': 'Resident Advisor', 'url': 'http://www.residentadvisor.net/'})
        headers = {'content-type': 'application/json'}
        ra = post(url + 'third_party', data=ra_dict, headers=headers)
        if not ra.ok:
            raise Error('Coulnt insert third party')
    return ra.json()

# %%
import pandas as pd
from pandas import DataFrame, Series
import requests
from requests.utils import quote, unquote
import json

def response_to_dataframe(response, request_url):
    resp_dict = response.json()

    # Table request
    if 'objects' in resp_dict.keys():
        rows = resp_dict['objects']

    # single item request
    else: 
        rows = [resp_dict]

    df = DataFrame(rows)
    # We look one Colunn deep for further dataframes
    for col in df.columns:
        if isinstance(df[col][0], list):
            df[col] = df[col].apply(DataFrame)
        if isinstance(df[col][0], dict):
            df[col] = df[col].apply(lambda x: DataFrame([x]))
    df['server_url'] = df['id'].apply(lambda id: request_url + '/' + str(id))
    return df

def get_df(table_name, item_id = None, query = None, url=event_db_url):
    url = url.rstrip('/') + '/'
    table_name = table_name.rstrip('/')
    request_url = url + table_name
    if item_id:
        response = requests.get(request_url + '/' + str(item_id))
    else:
        if query:
            q = json.dumps(query)
            params = {'q': q}
        else:
            params = None
        response = requests.get(request_url, params=params)
        
    if response.ok:
        df = response_to_dataframe(response, request_url)
        
    else:
        raise IOError(response.status_code)
    
    return df

# %%
import datetime

# %%
start_datetime = datetime.date(2014, 10, 22).isoformat()

query = {'filters':[{'name': 'start_date', 'op': '<=', 'val': start_datetime}]}
df = get_df('performance')

# %%
df
# Out:
#                                               artist  artist_id  \
# 0     id last_modified     name  source_id  text
# ...          1
# 1     id last_modified     name  source_id  text
# ...          1
# 2     id last_modified     name  source_id  text
# ...          1
#
#                                                event  event_id  id  kind  \
# 0    description         end_datetime  id last_mo...         1   1  None
# 1    description         end_datetime  id last_mo...         1   2  None
# 2    description         end_datetime  id last_mo...         1   3  None
#
#    kind_id          name  time                               server_url
# 0        1  PerformanceA  None  http://localhost:5000/api/performance/1
# 1        1  PerformanceB  None  http://localhost:5000/api/performance/2
# 2        2  PerformanceC  None  http://localhost:5000/api/performance/3
#
# [3 rows x 10 columns]

# %%
datetime.datetime(2014, 10, 11, 16, 0).isoformat()
# Out:
# '2014-10-11T16:00:00'

# %%
def venues_by_time(after, before):
    '''
        get event dataframe with query
        get venue dataframe
        inner join
        create layer-json with embedded venues
        layer-json contains:
            name
            before
            after
            link to self
            embedded features:
                lat
                lon
                link to venue-json by time
                name
                (label pos)
        return layer-json
        
    '''
    pass

def venue_events_by_time(venue_url, after, before):
    ''' 
        get event dataframe with query
        filter by venue_url
        create venue-json with embedded events:
        venue-json contains:
            name
            description
            adress-string
            lat
            lon
            q:
            before
            after
            embedded events:
                startdatetime
                enddatetime
                title
                artists: [{name, sc_url}]
                
            
    '''
    pass


def df_to_hal()

# %%
df
# Out:
#                                         artist_pages  \
# 0     artist_id  id resource_id  third_party_id  ...
# 1     artist_id  id resource_id  third_party_id  ...
# 2  Empty DataFrame
# Columns: []
# Index: []
#
# [0 rows...
#
#                                          event_pages  id              name  \
# 0     event_id  id resource_id  third_party_id   ...   1       thirdPartyA
# 1     event_id  id resource_id  third_party_id   ...   2       thirdPartyB
# 2  Empty DataFrame
# Columns: []
# Index: []
#
# [0 rows...   3  Resident Advisor
#
#                                url  \
# 0            http://thirdpartya.de
# 1            http://thirdpartyb.de
# 2  http://www.residentadvisor.net/
#
#                                          venue_pages  \
# 0     id resource_id  third_party_id             ...
# 1  Empty DataFrame
# Columns: []
# Index: []
#
# [0 rows...
# 2  Empty DataFrame
# Columns: []
# Index: []
#
# [0 rows...
#
#                                 server_url
# 0  http://localhost:5000/api/third_party/1
# 1  http://localhost:5000/api/third_party/2
# 2  http://localhost:5000/api/third_party/3
#
# [3 rows x 7 columns]
